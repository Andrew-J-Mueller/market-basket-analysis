# %% [markdown]
# ## 01. Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing data files "4.6_orders_products_combined.pkl" & "4.5_df_prods_clean.csv"

# %%
#set path
path = r"C:\Users\andre\OneDrive\Documents\coursework 2022\CF\Immersion\Achievement 4\Instacart Basket Analysis"

# %%
#import merged dataframe, drop indicator row
df_ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.6_orders_products_combined.pkl')).drop(['_merge'], axis = 1)

# %%
#check
df_ords_prods_comb
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32434484   2977660   206209    prior            13                   1
# 32434485   2977660   206209    prior            13                   1
# 32434486   2977660   206209    prior            13                   1
# 32434487   2977660   206209    prior            13                   1
# 32434488   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
#import cleaned products 
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', '4.5_df_prods_clean.csv')).drop(['Unnamed: 0'], axis = 1)

# %%
#check
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# ## 03. Merge

# %%
df_mrg_ords_prior_prods = df_ords_prods_comb.merge(df_prods, on = 'product_id', indicator = True)

# %%
#check
df_mrg_ords_prior_prods
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# ### inner merge dropped 30K rows or <1%

# %%
#check merge column 
df_mrg_ords_prior_prods['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#export to pkl
df_mrg_ords_prior_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.6_mrg_part2.pkl'))
