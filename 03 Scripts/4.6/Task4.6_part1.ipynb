# %% [markdown]
# ## 4.6 Merging Data Frame Exercise Part 1
#
# ### 01. Importing Libraries
# ### 02. Importing data files
# ### 03. Checking shape etc for merge
# ### 04. Merging data frames

# %% [markdown]
# ## 01. Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing data files "orders_products_prior.csv" & "4.5_df_orders_clean.csv"

# %%
#set path
path = r"C:\Users\andre\OneDrive\Documents\coursework 2022\CF\Immersion\Achievement 4\Instacart Basket Analysis"

# %%
#import cleaned orders 
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', '4.5_df_orders_clean.csv')).drop(['Unnamed: 0'], axis = 1)

# %%
#check
df_ords
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 1         2398795        1    prior             2                   3
# 2          473747        1    prior             3                   3
# 3         2254736        1    prior             4                   4
# 4          431534        1    prior             5                   4
# ...           ...      ...      ...           ...                 ...
# 3421078   2266710   206209    prior            10                   5
# 3421079   1854736   206209    prior            11                   4
# 3421080    626363   206209    prior            12                   1
# 3421081   2977660   206209    prior            13                   1
# 3421082    272231   206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
#import new 'prior' data file 
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '4.6_order_products_prior', 'order_products_prior.csv'), index_col = False)

# %%
#check
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %% [markdown]
# ## 03. check shape for merge

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# ## 04. Merge dataframes: default = inner join

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#check
df_merged_large
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32434484   2977660   206209    prior            13                   1
# 32434485   2977660   206209    prior            13                   1
# 32434486   2977660   206209    prior            13                   1
# 32434487   2977660   206209    prior            13                   1
# 32434488   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
#check merge column 
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#export to pkl
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.6_orders_products_combined.pkl'))
