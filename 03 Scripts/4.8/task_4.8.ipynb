# %% [markdown]
# # Task 4.8
# ### contents
#
# ### 1. import libraries
# ### 2. import data
# ### Task Question 2
# ### Task Question 3
# ### Task Question 4
# ### Task Question 5
# ### Task Question 6
# ### Task Question 7

# %% [markdown]
# ### 1. import libraries

# %%
import pandas as pd
import numpy as np
import os
import time

# %% [markdown]
# ### 2. import task 4.6 final merged data file

# %%
# %%time
path = r"C:\Users\andre\OneDrive\Documents\coursework 2022\CF\Immersion\Achievement 4\Instacart Basket Analysis\02 Data\Prepared Data\4.7.pkl"
ords_prods_merge = pd.read_pickle(path)
# Out:
# CPU times: total: 11.5 s
# Wall time: 15.3 s

# %% [markdown]
# ### check

# %%
# %%time
ords_prods_merge
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#          order_id user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329       1    prior             1                   2
# 1         2398795       1    prior             2                   3
# 2          473747       1    prior             3                   3
# 3         2254736       1    prior             4                   4
# 4          431534       1    prior             5                   4
# ...           ...     ...      ...           ...                 ...
# 32404854  1320836  202557    prior            17                   2
# 32404855    31526  202557    prior            18                   5
# 32404856   758936  203436    prior             1                   2
# 32404857  2745165  203436    prior             2                   3
# 32404858  3093936  205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# #drop the duplicated column price_range (user defined function- if statement- from 4.7)

# %%
# %%time
ords_prods_merge = pd.read_pickle(path).drop(['price_range'], axis = 1)
# Out:
# CPU times: total: 16.8 s
# Wall time: 18.2 s

# %%
# %%time
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 18 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  price_range_loc         object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
# dtypes: float64(2), int64(8), object(8)
# memory usage: 4.6+ GB
# CPU times: total: 0 ns
# Wall time: 3.01 ms

# %%
# %%time
ords_prods_merge.describe()
# Out:
# CPU times: total: 5.53 s
# Wall time: 5.78 s
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.240486e+07        3.240486e+07       3.240486e+07
# mean   1.714230e+01        2.738867e+00       1.342515e+01
# std    1.753532e+01        2.090077e+00       4.246380e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.400000e+01        5.000000e+00       1.600000e+01
# max    9.900000e+01        6.000000e+00       2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count            3.032876e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean             1.110408e+01  2.559866e+04       8.352547e+00  5.895873e-01
# std              8.779064e+00  1.408400e+04       7.127071e+00  4.919087e-01
# min              0.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# ...

# %% [markdown]
# ### Task 2.
# ### find the aggregated mean of the “order_number” column grouped by “department_id”

# %%
# %%time
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
# CPU times: total: 484 ms
# Wall time: 524 ms
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
#output from excercise subset
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# ### Task 3.
# ### comparing the output from subset with entire data set:
# * most mean values are higher in the subset.
# > the subset contained first 1M rows which seem to be grouped by the user id increasing. <br>
# > assuming user_id: 1 is the first customer...<br>
# > therefore, higher mean values suggest the earliest users average a larger number of orders than the entire data set <br>
# > this makes sense as those users had more time to place the orders <br>
# * subset contains less than half of total department offerings
# > seems odd that in the first 1M rows only 8 of 21 departments are represented

# %% [markdown]
# ### multiple aggregations

# %%
# %%time
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
# CPU times: total: 734 ms
# Wall time: 746 ms
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# ### Task 4. using transform() function to aggregate with criteria:
# * If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# * If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# * If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
# %%time
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# CPU times: total: 2.92 s
# Wall time: 3.1 s

# %%
#change default settings to allow for display of 100 rows 
pd.options.display.max_rows = 100

# %% [markdown]
# #check

# %%
# %%time
ords_prods_merge.head(100)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2398795       1    prior             2                   3
# 2    473747       1    prior             3                   3
# 3   2254736       1    prior             4                   4
# 4    431534       1    prior             5                   4
# 5   3367565       1    prior             6                   2
# 6    550135       1    prior             7                   1
# 7   3108588       1    prior             8                   1
# 8   2295261       1    prior             9                   1
# 9   2550362       1    prior            10                   4
# 10  2968173      15    prior            15                   1
# 11  1870022      15    prior            17                   2
# 12  1911383      15    prior            18                   2
# ...

# %% [markdown]
# ### create flag column using loc() based on the criteria above

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#check
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#check 60 rows of select columns (optimized code) sq brackets required to indicate a list, also the variables to call
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#    user_id      loyalty_flag  order_number
# 0        1      New customer             1
# 1        1      New customer             2
# 2        1      New customer             3
# 3        1      New customer             4
# 4        1      New customer             5
# 5        1      New customer             6
# 6        1      New customer             7
# 7        1      New customer             8
# 8        1      New customer             9
# 9        1      New customer            10
# 10      15  Regular customer            15
# 11      15  Regular customer            17
# 12      15  Regular customer            18
# 13      15  Regular customer            21
# 14      15  Regular customer            22
# 15      19      New customer             2
# 16      19      New customer             5
# 17      19      New customer             7
# 18      21  Regular customer            10
# 19      31  Regular customer            10
# 20      31  Regular customer            17
# ...

# %% [markdown]
# ### Task 5.
# ### Is there a difference between the spending habits of the three customer types identified?

# %%
# %%time
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
# CPU times: total: 1.8 s
# Wall time: 1.97 s
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# #### * results show on average, loyal customers spend the least, followed by regular, then new.
# #### * the range, however, is very high.
# ####  * results here show user_id: 1 as a new customer which is contrary to my assumption from above. further study of the data dictionary is needed.

# %% [markdown]
# ### Task 6.
# * Create a spending flag for each user based on the average price across all their orders using the following criteria:
# > If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”<br>
# > If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# %%time
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.average)
# Out:
# CPU times: total: 24.2 s
# Wall time: 25.3 s

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
#check
ords_prods_merge[['user_id', 'spending_flag']].head(60)
# Out:
#    user_id spending_flag
# 0        1   Low spender
# 1        1   Low spender
# 2        1   Low spender
# 3        1   Low spender
# 4        1   Low spender
# 5        1   Low spender
# 6        1   Low spender
# 7        1   Low spender
# 8        1   Low spender
# 9        1   Low spender
# 10      15   Low spender
# 11      15   Low spender
# 12      15   Low spender
# 13      15   Low spender
# 14      15   Low spender
# 15      19   Low spender
# 16      19   Low spender
# 17      19   Low spender
# 18      21   Low spender
# 19      31   Low spender
# 20      31   Low spender
# 21      43   Low spender
# 22      43   Low spender
# 23      52   Low spender
# 24      52   Low spender
# 25      52   Low spender
# 26      52   Low spender
# 27      52   Low spender
# 28      52   Low spender
# 29      52   Low spender
# 30      52   Low spender
# 31      52   Low spender
# 32      52   Low spender
# 33      52   Low spender
# 34      52   Low spender
# 35      52   Low spender
# ...

# %%
# %%time
ords_prods_merge.groupby('spending_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
# CPU times: total: 1.66 s
# Wall time: 1.76 s
#                    prices
#                      mean  min      max
# spending_flag
# High spender   222.354412  1.0  99999.0
# Low spender      7.780687  1.0     25.0

# %% [markdown]
# #### * mean values suggest huge gap in customer purchasing
# #### * the range is still unclear, is the max capped?

# %% [markdown]
# ### Task 7.
# * Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:<br>
# >If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”<br>
# >If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”<br>
# >If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# %%time
ords_prods_merge['median_dspo'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# CPU times: total: 3.66 s
# Wall time: 3.88 s

# %%
ords_prods_merge.loc[ords_prods_merge['median_dspo'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_dspo'] <= 20) & (ords_prods_merge['median_dspo'] >= 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_dspo'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
#check
ords_prods_merge[['user_id', 'frequency_flag']].head(60)
# Out:
#    user_id         frequency_flag
# 0        1  Non-frequent customer
# 1        1  Non-frequent customer
# 2        1  Non-frequent customer
# 3        1  Non-frequent customer
# 4        1  Non-frequent customer
# 5        1  Non-frequent customer
# 6        1  Non-frequent customer
# 7        1  Non-frequent customer
# 8        1  Non-frequent customer
# 9        1  Non-frequent customer
# 10      15      Frequent customer
# 11      15      Frequent customer
# 12      15      Frequent customer
# 13      15      Frequent customer
# 14      15      Frequent customer
# 15      19      Frequent customer
# 16      19      Frequent customer
# 17      19      Frequent customer
# 18      21      Frequent customer
# 19      31      Frequent customer
# 20      31      Frequent customer
# 21      43      Frequent customer
# 22      43      Frequent customer
# 23      52      Frequent customer
# 24      52      Frequent customer
# 25      52      Frequent customer
# ...

# %%
ords_prods_merge.groupby('frequency_flag').agg({'days_since_prior_order': ['mean', 'min', 'max']})
# Out:
#                       days_since_prior_order
#                                         mean  min   max
# frequency_flag
# Frequent customer                   7.877332  0.0  30.0
# Non-frequent customer              23.313946  0.0  30.0
# Regular customer                   15.556975  0.0  30.0

# %%
#save file as pkl
ords_prods_merge.to_pickle(r'C:\Users\andre\OneDrive\Documents\coursework 2022\CF\Immersion\Achievement 4\Instacart Basket Analysis\02 Data\Prepared Data\4.8.pkl')
